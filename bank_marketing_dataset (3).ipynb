# %% [markdown]
# ## Bank Marketing Dataset

# %% [markdown]
# ##### Predicting Term Deposite Suscriptions

# %% [markdown]
# ##### Let's start with importing libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# #### Loading dataset

# %%
bank = pd.read_csv(r"C:\Users\taigk\OneDrive\Documents\Desktop\my_sql.com\pizza_sales\bank.csv")        #loading dataet

# %% [markdown]
# ##### let's start with the first few steps

# %%
bank          #first view of my dataset
# Out:
#        age          job  marital  education default  balance housing loan  \
# 0       59       admin.  married  secondary      no     2343     yes   no
# 1       56       admin.  married  secondary      no       45      no   no
# 2       41   technician  married  secondary      no     1270     yes   no
# 3       55     services  married  secondary      no     2476     yes   no
# 4       54       admin.  married   tertiary      no      184      no   no
# ...    ...          ...      ...        ...     ...      ...     ...  ...
# 11157   33  blue-collar   single    primary      no        1     yes   no
# 11158   39     services  married  secondary      no      733      no   no
# 11159   32   technician   single  secondary      no       29      no   no
# 11160   43   technician  married  secondary      no        0      no  yes
# 11161   34   technician  married  secondary      no        0      no   no
#
#         contact  day month  duration  campaign  pdays  previous poutcome  \
# ...

# %%
bank.head()     #first five row
# Out:
#    age         job  marital  education default  balance housing loan  contact  \
# 0   59      admin.  married  secondary      no     2343     yes   no  unknown
# 1   56      admin.  married  secondary      no       45      no   no  unknown
# 2   41  technician  married  secondary      no     1270     yes   no  unknown
# 3   55    services  married  secondary      no     2476     yes   no  unknown
# 4   54      admin.  married   tertiary      no      184      no   no  unknown
#
#    day month  duration  campaign  pdays  previous poutcome deposit
# 0    5   may      1042         1     -1         0  unknown     yes
# 1    5   may      1467         1     -1         0  unknown     yes
# 2    5   may      1389         1     -1         0  unknown     yes
# 3    5   may       579         1     -1         0  unknown     yes
# 4    5   may       673         2     -1         0  unknown     yes

# %%
bank.tail()            #last five row
# Out:
#        age          job  marital  education default  balance housing loan  \
# 11157   33  blue-collar   single    primary      no        1     yes   no
# 11158   39     services  married  secondary      no      733      no   no
# 11159   32   technician   single  secondary      no       29      no   no
# 11160   43   technician  married  secondary      no        0      no  yes
# 11161   34   technician  married  secondary      no        0      no   no
#
#         contact  day month  duration  campaign  pdays  previous poutcome  \
# 11157  cellular   20   apr       257         1     -1         0  unknown
# 11158   unknown   16   jun        83         4     -1         0  unknown
# 11159  cellular   19   aug       156         2     -1         0  unknown
# 11160  cellular    8   may         9         2    172         5  failure
# 11161  cellular    9   jul       628         1     -1         0  unknown
#
#       deposit
# 11157      no
# 11158      no
# 11159      no
# 11160      no
# ...

# %%
bank.shape              #to get to know about the row and columns
# Out:
# (11162, 17)

# %%
bank.columns        #to get to know about the columns name
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'balance', 'housing',
#        'loan', 'contact', 'day', 'month', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome', 'deposit'],
#       dtype='object')

# %%
bank.info()          #to get to know the datatypes of my dataset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11162 entries, 0 to 11161
# Data columns (total 17 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        11162 non-null  int64
#  1   job        11162 non-null  object
#  2   marital    11162 non-null  object
#  3   education  11162 non-null  object
#  4   default    11162 non-null  object
#  5   balance    11162 non-null  int64
#  6   housing    11162 non-null  object
#  7   loan       11162 non-null  object
#  8   contact    11162 non-null  object
#  9   day        11162 non-null  int64
#  10  month      11162 non-null  object
#  11  duration   11162 non-null  int64
#  12  campaign   11162 non-null  int64
#  13  pdays      11162 non-null  int64
#  14  previous   11162 non-null  int64
#  15  poutcome   11162 non-null  object
#  16  deposit    11162 non-null  object
# dtypes: int64(7), object(10)
# memory usage: 1.4+ MB

# %%
bank.describe()           #to get done all arithmetic function
# Out:
#                 age       balance           day      duration      campaign  \
# count  11162.000000  11162.000000  11162.000000  11162.000000  11162.000000
# mean      41.231948   1528.538524     15.658036    371.993818      2.508421
# std       11.913369   3225.413326      8.420740    347.128386      2.722077
# min       18.000000  -6847.000000      1.000000      2.000000      1.000000
# 25%       32.000000    122.000000      8.000000    138.000000      1.000000
# 50%       39.000000    550.000000     15.000000    255.000000      2.000000
# 75%       49.000000   1708.000000     22.000000    496.000000      3.000000
# max       95.000000  81204.000000     31.000000   3881.000000     63.000000
#
#               pdays      previous
# count  11162.000000  11162.000000
# mean      51.330407      0.832557
# std      108.758282      2.292007
# min       -1.000000      0.000000
# 25%       -1.000000      0.000000
# 50%       -1.000000      0.000000
# 75%       20.750000      1.000000
# ...

# %% [markdown]
# #### let's starts dealing with the dataset

# %%
bank.isnull().sum()          #to get to know about my dataset value is there any null
# Out:
# age          0
# job          0
# marital      0
# education    0
# default      0
# balance      0
# housing      0
# loan         0
# contact      0
# day          0
# month        0
# duration     0
# campaign     0
# pdays        0
# previous     0
# poutcome     0
# deposit      0
# dtype: int64

# %% [markdown]
# #### Bivariate Analysis

# %%
bank = bank.groupby('age')['job'].count().reset_index()         #grouping while having 'age'

# %%
# this graph will represent the customer's age
plt.figure(figsize=(4,5))
plt.bar(bank['age'], bank['job'], color='DarkBlue')
plt.title('Customers_Age!!', c='black')
plt.ylabel('Number_Of_Customers', c='black')
plt.xlabel('Age_Group', c='black')
plt.tight_layout()
plt.show()

# %%
bank= bank.groupby('job')['age'].count().reset_index()          #grouping with the 'job' while having 'age'

# %%
#this group will show the jobs with the category
plt.figure(figsize=(5,5))
plt.barh(bank['job'], bank['age'], color='darkGreen')
plt.title('JOBs', c='r')
plt.ylabel('Category_Of_Jobs', c='r')
plt.xlabel('Number_of_employee', c='r')
plt.tight_layout()
plt.show()

# %%
bank_ma= bank.groupby('marital')['age'].count().reset_index()           #group by 'martial'

# %%
#this graph will stand for the marital statements
plt.figure(figsize=(3, 3))
alues= bank_ma['age'].values
labels= bank_ma['marital']
plt.pie(values , labels=labels ,autopct='%1.1f%%', colors=['blue','green','black'])
plt.title('MARITAL_STATEMENTS', c='black')
plt.tight_layout()
plt.show()

# %%
bank_ed=bank.groupby('education')['age'].count().reset_index() #grouping while 'education'

# %%
#this grapg will stand for education category
plt.figure(figsize=(4,4))
values= bank_ed['age'].values
labels= bank_ed['education']
plt.pie(values, labels=labels, autopct='%1.1f%%')
plt.title('Education_Status', c='blue')
plt.tight_layout()
plt.show()

# %%
bank_de=bank.groupby('default')['age'].count().reset_index()        #group by 'default'

# %%
#this circle will stand for default 
plt.figure(figsize=(4, 4))
values= bank_de['age'].values
labels=bank_de['default']
plt.pie(values, labels=labels , autopct='%1.1f%%', colors=['red', 'black'])
plt.title('Default', c='green')
plt.tight_layout()
plt.show()

# %%
bank_ho= bank.groupby('housing')['age'].count().reset_index()

# %%
#this circle will stand for house availability
plt.figure(figsize=(4,4))
values = bank_ho['age'].values
labels=bank_ho['housing']
plt.pie(values, labels=labels   ,autopct='%1.1f%%', colors=['yellow','green'])
plt.title('house availability', c='r')
plt.tight_layout()
plt.show()

# %%
bank_lo = bank.groupby('loan')['age'].count().reset_index()        #grouping with the loan availability

# %%
#this circle will stands for loans
plt.figure(figsize=(4,4))
values = bank_lo['age'].values
labels=bank_lo['loan']
plt.pie(values, labels=labels   ,autopct='%1.1f%%', colors=['blue','green'])
plt.title('LOANS', c='r')
plt.tight_layout()
plt.show()

# %%
 bank_co= bank.groupby('contact')['age'].count().reset_index() #group by 'contact_details'

# %%
#this circle will stands for contact information
plt.figure(figsize=(4,4))
values = bank_co['age'].values
labels=bank_co['contact']
plt.pie(values, labels=labels   ,autopct='%1.1f%%', colors=['yellow','blue', 'green'])
plt.title('CONTACT_Category', c='r')
plt.tight_layout()
plt.show()

# %%
bank_day= bank.groupby('day')['age'].count().reset_index()        #group by day of the month

# %%
#this line will stands for the customers coming days
plt.figure(figsize=(5,3))
plt.plot(bank_day['day'], bank_day['age'], color='maroon', marker='*')
plt.title('DYA_WISE_CUSTOMERS', c='black')
plt.xlabel('DAYS!!', c='black')
plt.ylabel('Number_of_customers',c='black')
plt.tight_layout()
plt.show()

# %%
bank_mon= bank.groupby('month')['age'].count().reset_index()  #grouping with the month

# %%
#this line represent the customers numbers in the year month wise
plt.plot(bank_mon['month'],bank_mon['age'], color='olive', marker='*')
plt.title('Customers', c='g')
plt.ylabel('Number_of_customers' ,c='g')
plt.xlabel('Month', c='g')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
bank_po= bank.groupby('poutcome')['age'].count().reset_index()         #grouping with the result ''poutcome'

# %%
#this circle will represent poutcome result
plt.figure(figsize=(4,4))
values = bank_po['age'].values
labels=bank_po['poutcome']
plt.pie(values , labels=labels , autopct='%1.1f%%')
plt.title('Poutcome_result',c='r')
plt.tight_layout()
plt.show()

# %%
bank_dep= bank.groupby('deposit')['age'].count().reset_index()   #grouping with 'deposit'

# %%
#this circle will represent deposit result
plt.figure(figsize=(4,4))
values = bank_dep['age'].values
labels=bank_dep['deposit']
plt.pie(values , labels=labels , autopct='%1.1f%%', colors=['black', 'green'])
plt.title('Deposit_result',c='r')
plt.tight_layout()
plt.show()

# %%
## 📌 Final Thoughts

This Exploratory Data Analysis (EDA) on the Bank
Marketing dataset focused on uncovering customer
insights and patterns that influence term deposit
subscriptions. By examining features such as age,
job type, marital status, education level, and default history, 
we visualized how different demographics are distributed
and how they might relate to customer decision-making.

Through bar charts and pie plots, this notebook highlights 
key trends and distributions in the data. The goal was
to build a strong foundation for further analysis or predictive 
modeling. This project serves as a valuable piece in my
data analytics journey and has been shared on GitHub 
and LinkedIn as part of my professional portfolio.

📂 *Dataset Source:* Bank Marketing Dataset  
📈 *Tech Stack Used:* Python, Pandas, Matplotlib, Seaborn  
💼 *Author:* Tiger (Aspiring Data Analyst)

Feel free to connect with me for feedback, collaboration, or opportunities!
